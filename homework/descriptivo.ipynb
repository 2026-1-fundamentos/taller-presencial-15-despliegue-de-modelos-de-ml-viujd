# %% [markdown]
# # Descriptivo del modelo
#
# Este notebook muestra una vista resumida del proceso de entrenamiento y uso del modelo.

# %%
from pathlib import Path
import pickle
import pandas as pd

from train_model import FEATURE_COLUMNS, train_and_save_model

bundle = train_and_save_model()
print(bundle['r2_score'])
print(bundle['features'])
